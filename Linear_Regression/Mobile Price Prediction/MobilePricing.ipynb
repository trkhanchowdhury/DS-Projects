# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
# Importing the Data From the file
df = pd.read_csv('Cellphone.csv')

# %%
df.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
# Checking Data Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
df.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# ...

# %%
# Checking all the columns
df.columns
# Out:
# Index(['Product_id', 'Price', 'Sale', 'weight', 'resoloution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'RearCam', 'Front_Cam',
#        'battery', 'thickness'],
#       dtype='object')

# %% [markdown]
# # Data analysis Using various Graphs

# %%
plt.title("Ram vs Price Comparison")
plt.xlabel("Ram")
plt.ylabel("Price of Phone")
plt.scatter(df['ram'] , df['Price'])
plt.show()

# %%
plt.title("Price Variation with Change in Front Camera Resolution")
plt.xlabel("Front camera")
plt.ylabel("Price")
plt.scatter(df['Front_Cam'],df['Price'])
plt.show()

# %%
sns.distplot(df['ram'] , color = 'blue')
plt.show()

# %%
sns.distplot(df['Front_Cam'] , color = 'green')
plt.show()

# %%
sns.distplot(df['weight'],color = 'red')
plt.show()

# %%
sns.distplot(df['Sale'],color='purple')
plt.show()

# %%
plt.title("Boxplot of Ram")
plt.xlabel("Data")
plt.ylabel("Values")
plt.boxplot(x='ram' , data=df )
plt.show()

# %%
sns.countplot(x='ram' , data=df)
plt.show()

# %%
sns.countplot(x='Price' , data=df)
plt.show()

# %%
sns.countplot(x='Front_Cam' , data=df)
plt.show()

# %%
sns.countplot(x='weight' , data=df)
plt.show()

# %%
sns.countplot(x="RearCam" , data=df)
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.title("Box Plot")
plt.xlabel("Data")
plt.ylabel("Values")

sns.boxplot(data=df)
plt.show()

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot: >

# %%
# Dividing data into X and y Variable
X = df[['Sale', 'weight', 'resoloution', 'ppi','cpu core', 'cpu freq', 'internal mem', 'ram', 'RearCam', 'Front_Cam','battery', 'thickness']]

# %%
y = df['Price']

# %%
# Feature Scaling of X so to convert data into Similar Range 
def featurescaling(X):
    Xmean = X.mean(axis=0)
    Xstd = X.std(axis=0)
    
    return (X - Xmean)/Xstd

# %%
X = featurescaling(X)

# %%
X.head()
# Out:
#        Sale    weight  resoloution       ppi  cpu core  cpu freq  \
# 0 -0.395357 -0.381382    -0.006582  0.659692  1.285940 -0.254813
# 1 -0.395357 -0.489038    -0.801308 -0.756942 -1.169036 -0.338176
# 2 -0.395357 -0.650522    -0.337718 -0.171004 -0.350711 -0.504903
# 3 -0.394710 -0.559015    -0.801308 -0.756942 -1.169036 -0.338176
# 4 -0.394710 -0.489038    -0.801308 -0.756942 -1.169036 -0.338176
#
#    internal mem       ram   RearCam  Front_Cam   battery  thickness
# 0     -0.295150  0.493844  0.424121   0.805355 -0.169798  -0.694045
# 1     -0.711747 -0.748522 -1.169322  -1.037091 -0.835493   0.446172
# 2     -0.572881 -0.437930  0.424121   0.114438 -0.616033  -0.602828
# 3     -0.711747 -1.051659 -1.169322  -1.037091 -1.054954   0.947868
# 4     -0.711747 -0.748522 -1.169322  -1.037091 -0.835493   0.446172

# %%
X.mean(axis=0),X.std(axis=0)
# Out:
# (Sale           -2.206654e-17
#  weight         -4.413309e-17
#  resoloution     3.309982e-16
#  ppi             1.930823e-16
#  cpu core        1.544658e-16
#  cpu freq       -5.516636e-17
#  internal mem   -2.206654e-17
#  ram            -1.930823e-16
#  RearCam         2.206654e-17
#  Front_Cam      -2.206654e-17
#  battery        -1.158494e-16
#  thickness       3.751313e-16
#  dtype: float64,
#  Sale            1.0
#  weight          1.0
#  resoloution     1.0
#  ppi             1.0
#  cpu core        1.0
#  cpu freq        1.0
#  internal mem    1.0
#  ram             1.0
#  RearCam         1.0
#  Front_Cam       1.0
#  battery         1.0
#  thickness       1.0
#  dtype: float64)

# %% [markdown]
# # Selecting Best Features From the Dataset

# %%
from sklearn.feature_selection import SelectKBest

# %%
best_features = SelectKBest()

# %%
fit = best_features.fit(X,y)

# %%
fit.scores_
# Out:
# array([  17.98543627, 1227.22694879,  597.02180226,  411.20471895,
#          58.73214286,   26.37611723,  517.57183359,  333.89574152,
#         678.32432367,  133.12843251, 2927.36662084,  130.48272018])

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featurescore = pd.concat([dfcolumns,dfscores],axis=1)

# %%
featurescore.columns = ['Features' , 'Scores']

# %%
featurescore
# Out:
#         Features       Scores
# 0           Sale    17.985436
# 1         weight  1227.226949
# 2    resoloution   597.021802
# 3            ppi   411.204719
# 4       cpu core    58.732143
# 5       cpu freq    26.376117
# 6   internal mem   517.571834
# 7            ram   333.895742
# 8        RearCam   678.324324
# 9      Front_Cam   133.128433
# 10       battery  2927.366621
# 11     thickness   130.482720

# %%
featurescore.sort_values(by='Scores' , ascending = False)
# Out:
#         Features       Scores
# 10       battery  2927.366621
# 1         weight  1227.226949
# 8        RearCam   678.324324
# 2    resoloution   597.021802
# 6   internal mem   517.571834
# 3            ppi   411.204719
# 7            ram   333.895742
# 9      Front_Cam   133.128433
# 11     thickness   130.482720
# 4       cpu core    58.732143
# 5       cpu freq    26.376117
# 0           Sale    17.985436

# %%
X.columns
# Out:
# Index(['Sale', 'weight', 'resoloution', 'ppi', 'cpu core', 'cpu freq',
#        'internal mem', 'ram', 'RearCam', 'Front_Cam', 'battery', 'thickness'],
#       dtype='object')

# %%
X_new = X[['battery','weight', 'RearCam' , 'resoloution' , 'internal mem' , 'ppi' , 'ram', 'Front_Cam',  'thickness' , 'cpu core' , 'cpu freq']]

# %%
X_new.head()
# Out:
#     battery    weight   RearCam  resoloution  internal mem       ppi  \
# 0 -0.169798 -0.381382  0.424121    -0.006582     -0.295150  0.659692
# 1 -0.835493 -0.489038 -1.169322    -0.801308     -0.711747 -0.756942
# 2 -0.616033 -0.650522  0.424121    -0.337718     -0.572881 -0.171004
# 3 -1.054954 -0.559015 -1.169322    -0.801308     -0.711747 -0.756942
# 4 -0.835493 -0.489038 -1.169322    -0.801308     -0.711747 -0.756942
#
#         ram  Front_Cam  thickness  cpu core  cpu freq
# 0  0.493844   0.805355  -0.694045  1.285940 -0.254813
# 1 -0.748522  -1.037091   0.446172 -1.169036 -0.338176
# 2 -0.437930   0.114438  -0.602828 -0.350711 -0.504903
# 3 -1.051659  -1.037091   0.947868 -1.169036 -0.338176
# 4 -0.748522  -1.037091   0.446172 -1.169036 -0.338176

# %% [markdown]
# # Applying Machine Learning Linear Regression Algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
Xtrain , Xtest , ytrain , ytest = train_test_split(X_new , y , test_size=0.3)

# %%
model = LinearRegression()

# %%
model.fit(Xtrain , ytrain)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(Xtest)

# %% [markdown]
# # Model evaluation

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(ytest,y_predict)

# %%
r2
# Out:
# 0.9597644979748705
