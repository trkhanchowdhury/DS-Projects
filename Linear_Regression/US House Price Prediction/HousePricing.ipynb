# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
plt.style.use("seaborn")
# Out:
# /var/folders/21/vgybxt6529g5wrtxj6dvczdm0000gn/T/ipykernel_5956/1929394360.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
data = pd.read_csv("data.csv")

data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 647.0+ KB

# %%
#Checking the Total number of columns
data.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 18

# %%
# Seeing the relation between different columns and price
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.scatter(data["bedrooms"] , data["price"])

# %%
plt.xlabel("bathrooms")
plt.ylabel("Price")
plt.scatter(data["bathrooms"] , data["price"])

# %%
plt.xlabel("sqft_living")
plt.ylabel("Price")
plt.scatter(data["sqft_living"] , data["price"],color="purple")

# %%
plt.xlabel("sqft_lot")
plt.ylabel("Price")
plt.scatter(data["sqft_lot"] , data["price"])

# %%
plt.xlabel("floors")
plt.ylabel("Price")
plt.scatter(data["floors"] , data["price"])

# %%
plt.xlabel("waterfront")
plt.ylabel("Price")
plt.scatter(data["waterfront"] , data["price"] , color = "orange")

# %%
plt.xlabel("view")
plt.ylabel("Price")
plt.scatter(data["view"] , data["price"])

# %%
plt.xlabel("condition")
plt.ylabel("Price")
plt.scatter(data["condition"] , data["price"])

# %%
plt.xlabel("sqft_above")
plt.ylabel("Price")
plt.scatter(data["sqft_above"] , data["price"])

# %%
plt.xlabel("sqft_basement")
plt.ylabel("Price")
plt.scatter(data["sqft_basement"] , data["price"])

# %%
plt.xlabel("yr_built")
plt.ylabel("Price")
plt.scatter(data["yr_built"] , data["price"])

# %%
plt.xlabel("yr_renovated")
plt.ylabel("Price")
plt.scatter(data["yr_renovated"] , data["price"])

# %%
plt.figure(figsize=(12,7))
sns.heatmap(data.corr(),annot=True)
plt.show()
# Out:
# /var/folders/21/vgybxt6529g5wrtxj6dvczdm0000gn/T/ipykernel_5956/745092901.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)

# %%
X = data[[ 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot','floors', 'waterfront', 'view', 'condition', 'sqft_above','sqft_basement', 'yr_built', 'yr_renovated']]
       
y = data["price"]

# %%
def featurescaling(X):
    """Doing Feature scaling so that every feature came into relatively same region"""
    Xmean = X.mean(axis=0)
    X_std = X.std(axis=0)
    
    return (X - Xmean)/X_std

# %%
X = featurescaling(X)
X.mean(axis=0),X.std(axis=0)
# Out:
# (price            6.255865e-17
#  bedrooms         6.024167e-17
#  bathrooms       -1.266620e-16
#  sqft_living     -1.050368e-16
#  sqft_lot        -1.467425e-17
#  floors           1.606444e-16
#  waterfront       1.544658e-17
#  view             9.267949e-18
#  condition        3.259229e-16
#  sqft_above      -3.707179e-17
#  sqft_basement   -2.934850e-17
#  yr_built         3.273131e-15
#  yr_renovated     4.556741e-17
#  dtype: float64,
#  price            1.0
#  bedrooms         1.0
#  bathrooms        1.0
#  sqft_living      1.0
#  sqft_lot         1.0
#  floors           1.0
#  waterfront       1.0
#  view             1.0
#  condition        1.0
#  sqft_above       1.0
#  sqft_basement    1.0
#  yr_built         1.0
#  yr_renovated     1.0
#  dtype: float64)

# %%
# Outlier Removal 
# Removing the outlier from the dataset to get the best prediction
z_scores = (X - X.mean()) / X.std()
z_score_threshold = 3
outlier_indices = np.where(np.abs(z_scores) > z_score_threshold)
X = X.drop(outlier_indices[0])
y = y.drop(outlier_indices[0])

# %%
X.shape,y.shape
# Out:
# ((4238, 13), (4238,))

# %%
# Spliting the Dataset into Training and testing set
Xtrain , Xtest , ytrain , ytest = train_test_split(X,y , shuffle=False , random_state=0)

# %%
n_features = X.shape[1]
# Adding the additional column into the X
def preprocess(X):
    if X.shape[1]==n_features:
        m = X.shape[0]
        ones = np.zeros((m,1))
        X = np.hstack((ones,X))
        
    return X

# %%
# Defining the hypothesis function
def hypothesis(X,theta):
    """This is the hypothesis Function"""
    return np.dot(X,theta)
# Defining the costfunction
def costfunction(X,y,theta):
    """Costfunction checks how well the model is performing."""
    m = X.shape[0]
    error = np.sum((hypothesis(X,theta) - y)**2)
    return error/(2*m)

def derivative(X,y,theta):
    
    m = X.shape[0]
    y_predict = hypothesis(X,theta)
    derive = np.dot(X.T,(y_predict-y))
    
    return derive/m

# %%
X.shape[1]
# Out:
# 13

# %%
# Defining the function to get best value of parameters
def train(X,y,alpha = 0.6 , max_itrs = 1500):
    n = X.shape[1]
    theta = np.random.randn(n)
    error_list = []
    
    for i in range(max_itrs):
        e = costfunction(X,y,theta)
        error_list.append(e)
        derive = derivative(X,y,theta)
        theta = theta - alpha*derive
        
    plt.plot(error_list)
    return theta

# %%
Xtrain  = preprocess(Xtrain)
train1 = train(Xtrain , ytrain)

# %%
Xtest = preprocess(Xtest)
y_predict = hypothesis(Xtest , train1)

# %%
# R2score function which will give the final performance of the model 
def evaluation(y,y_predict):
    ymean = y.mean()
    num = np.sum((y - y_predict)**2)
    denom = np.sum((y - ymean)**2)
    
    return 1 - num/denom

# %%
evaluate = evaluation(ytest,y_predict)
evaluate
# Out:
# 0.9999126136802532
